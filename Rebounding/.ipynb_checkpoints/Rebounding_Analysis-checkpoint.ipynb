# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import IsolationForest
warnings.filterwarnings('ignore')

# %%
headers = {
  'Referer': 'https://stats.nba.com/players/shots-dribbles',
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
  'x-nba-stats-origin': 'stats'
}
def get_game_logs(url="https://stats.nba.com/stats/leaguegamefinder?",PlayerOrTeam= "T",LeagueID= "00",Season= '2019-20',
                       SeasonType= 'Playoffs',TeamID= '',VsTeamID= '',PlayerID= '',GameID= '',Outcome= '',Location= '',DateFrom= '',
                       DateTo= '',VsConference= '',VsDivision= '',Conference= '',Division= '',DraftYear= '',DraftNumber= '',
                       DraftRound= '',DraftTeamID= '',RookieYear= '',YearsExperience= '',SeasonSegment= '',PORound= '',
                       StarterBench= '',GtPTS= '',GtREB= '',GtAST= '',GtSTL= '',GtBLK= '',GtOREB= '',GtDREB= '',GtDD= '',
                       GtTD= '',GtMINUTES= '',GtTOV= '',GtPF= '',GtFGM= '',GtFGA= '',GtFG_PCT= '',GtFTM= '',GtFTA= '',
                       GtFT_PCT= '',GtFG3M= '',GtFG3A= '',GtFG3_PCT= '',LtPTS= '',LtREB= '',LtAST= '',LtSTL= '',LtBLK= '',
                       LtOREB= '',LtDREB= '',LtDD= '',LtTD= '',LtMINUTES= '',LtTOV= '',LtPF= '',LtFGM= '',LtFGA= '',
                       LtFG_PCT= '',LtFTM= '',LtFTA= '',LtFT_PCT= '',LtFG3M= '',LtFG3A= '',LtFG3_PCT= '',EqPTS= '',
                       EqREB= '',EqAST= '',EqSTL= '',EqBLK= '',EqOREB= '',EqDREB= '',EqDD= '',EqTD= '',EqMINUTES= '',
                       EqTOV= '',EqPF= '',EqFGM= '',EqFGA= '',EqFG_PCT= '',EqFTM= '',EqFTA= '',EqFT_PCT= '',EqFG3M= '',
                       EqFG3A= '',EqFG3_PCT= ''):
    api_param = locals()
    payload = {}
    response = requests.request("GET",url,params=api_param,headers=headers,data = payload)
    data = response.json()
    df = pd.DataFrame(data['resultSets'][0]['rowSet'],columns=data['resultSets'][0]['headers'])
    return df

def seasons_string(start,end):
    '''
    creates a list of NBA seasons from start-end
    '''
    years = np.arange(start,end+1)
    seasons = []
    for year in years:
        string1 = str(year)
        string2 = str(year+1)
        season = '{}-{}'.format(string1,string2[-2:])
        seasons.append(season)
    return seasons

# %%
seasonType="Regular Season"
team_game_logs_df = get_game_logs(SeasonType=seasonType)

# %%
team_game_logs_df_reb = team_game_logs_df[["WL","OREB","REB","DREB","GAME_ID","TOV"]]
merge_df = team_game_logs_df_reb[team_game_logs_df_reb["WL"] == 'W'].merge(team_game_logs_df_reb[team_game_logs_df_reb["WL"] == 'L'],on="GAME_ID")

# %%
merge_df["REB_DIFF"] = merge_df["REB_x"] - merge_df["REB_y"]
merge_df["DREB_PCT_x"] = merge_df["DREB_x"] / (merge_df["DREB_x"] + merge_df["OREB_y"])
merge_df["DREB_PCT_y"] = merge_df["DREB_y"] / (merge_df["DREB_y"] + merge_df["OREB_x"])
merge_df["REB_PCT_DIFF"] = merge_df["DREB_PCT_x"] - merge_df["DREB_PCT_y"]

# %%
merge_df["REB_DIFF_SIGN"] = np.where(merge_df["REB_DIFF"] < 0 , -1 , 1)
merge_df["REB_PCT_DIFF_SIGN"] = np.where(merge_df["REB_PCT_DIFF"] < 0 , -1 , 1)
merge_df["REB_PCT_DIFF_GROUP"] = np.sign(merge_df["REB_PCT_DIFF"]) * np.floor((abs(merge_df["REB_PCT_DIFF"]) * 10))
games_count = len(merge_df.index)

# %%
count_column = "DREB_x"
REB_group_columns = ["REB_PCT_DIFF_SIGN","REB_DIFF_SIGN"]
for REB_group_column in REB_group_columns:
    temp_df = ((merge_df.groupby(REB_group_column)[count_column].count() / games_count).reset_index(name="WIN_PRECENTAGE"))
    temp_df["Reason"] = np.where(temp_df[REB_group_column] == -1 , "team win when loose at rebound","team win when win at rebound")
    ax =temp_df.set_index("Reason").plot.pie(y="WIN_PRECENTAGE",autopct="%1.1f%%", textprops={'fontsize': 14} ,legend=False,shadow=True, startangle=90,colors=["salmon","lightgreen"])
    ax.set_ylabel('')

# %%
merge_df["ABS_REB_PCT_DIFF_GROUP"] = abs(merge_df["REB_PCT_DIFF_GROUP"])
merge_df["IS_SIGN_POSITIVE"] = np.where(merge_df["REB_PCT_DIFF_SIGN"] == 1 , 1 , 0)
plot_df = (merge_df.groupby("ABS_REB_PCT_DIFF_GROUP")["IS_SIGN_POSITIVE"].sum() / merge_df.groupby("ABS_REB_PCT_DIFF_GROUP")["REB_PCT_DIFF_SIGN"].count())

ax = plot_df.plot(xticks=[0,1,2,3])
ax.set_xlim(0,3.2)
ax.set_ylim(0.5,1.05)
for row in plot_df.items():
     ax.annotate(round(row[1],2), xy=(row[0], row[1] + 0.02))

plot_df
# Out:
# ABS_REB_PCT_DIFF_GROUP
# 0.0    0.577994
# 1.0    0.643357
# 2.0    0.679245
# 3.0    1.000000
# dtype: float64

# %%
merge_df.sort_values("DREB_PCT_y",ascending=True)
# Out:
#      WL_x  OREB_x  REB_x  DREB_x     GAME_ID  TOV_x WL_y  OREB_y  REB_y  \
# 342     W      19     57      38  0021900715     18    L      16     38
# 168     W      17     50      33  0021900887     16    L      13     33
# 1017    W      25     63      38  0021900042     17    L       8     38
# 155     W      20     65      45  0021900903     17    L       8     34
# 148     W      22     63      41  0021900910     20    L      13     42
# 386     W      24     56      32  0021900676     11    L      12     45
# 612     W      17     48      31  0021900445     12    L       6     30
# 801     W      19     55      36  0021900253     14    L      11     38
# 334     W      16     57      41  0021900723     19    L      11     34
# 657     W      16     51      35  0021900401     16    L      10     33
# 747     W      18     53      35  0021900309     15    L       9     35
# 394     W      18     53      35  0021900662     17    L      13     40
# 998     W      19     44      25  0021900061     13    L      11     40
# 822     W      19     52      33  0021900238     10    L       7     36
# 278     W      16     47      31  0021900779     15    L       3     28
# 1025    W      21     53      32  0021900033      9    L       8     41
# 1008    W      19     61      42  0021900047     18    L      11     41
# 222     W      17     47      30  0021900839     19    L      11     38
# 618     W      17     44      27  0021900443      8    L      18     45
# 582     W      15     53      38  0021900473     22    L       7     31
# 733     W      15     49      34  0021900320     16    L      10     34
# 398     W      23     63      40  0021900656     15    L       8     45
# 135     W      18     59      41  0021900920     11    L      13     42
# 777     W      13     52      39  0021900282     15    L       8     29
# 262     W      16     59      43  0021900801     16    L       3     29
# 864     W      19     47      28  0021900189      7    L      10     41
# 917     W      20     66      46  0021900145     19    L       5     38
# 743     W      20     54      34  0021900318     22    L      12     45
# 371     W      18     54      36  0021900691     18    L       7     37
# 548     W      15     47      32  0021900509     10    L       9     34
# ...   ...     ...    ...     ...         ...    ...  ...     ...    ...
# 1001    W       3     36      33  0021900063     14    L       6     36
# 735     W       3     45      42  0021900329     16    L       4     34
# 452       31     15       -10    0.704545    0.911765     -0.207219
# 1002      31     20        -8    0.738095    0.911765     -0.173669
# 763       31     18        -9    0.743590    0.911765     -0.168175
# 977       31     17         8    0.846154    0.911765     -0.065611
# 411       32     16         9    0.865385    0.914286     -0.048901
# 455       33     14        -2    0.804348    0.916667     -0.112319
# 63        33     14        -2    0.818182    0.916667     -0.098485
# 395       33     10         3    0.789474    0.916667     -0.127193
# 524       34     10        -4    0.764706    0.918919     -0.154213
# 378       34     13         2    0.851064    0.918919     -0.067855
# 987       35     13        -7    0.719298    0.921053     -0.201754
# 55        35     13         1    0.836735    0.921053     -0.084318
# 1026      25     17        12    0.872340    0.925926     -0.053586
# 133       38     15       -13    0.720000    0.926829     -0.206829
# 239       40     19       -24    0.685714    0.930233     -0.244518
# 140       27     17        -3    0.775000    0.931034     -0.156034
# 203       29     16         6    0.883721    0.935484     -0.051763
# 993       30     14         2    0.875000    0.937500     -0.062500
# 955       31     14        -6    0.744681    0.939394     -0.194713
# 58        32     18       -11    0.731707    0.941176     -0.209469
# 356       34     13         4    0.875000    0.944444     -0.069444
# 105       40     11       -14    0.772727    0.952381     -0.179654
# 714       41     14        -2    0.862745    0.953488     -0.090743
# 708       36     15        -4    0.803922    0.972973     -0.169051
# 402       28     14        -3    0.765957    1.000000     -0.234043
#
#       REB_DIFF_SIGN  REB_PCT_DIFF_SIGN  REB_PCT_DIFF_GROUP  \
# 342               1                  1                 1.0
# 168               1                  1                 1.0
# 1017              1                  1                 2.0
# 155               1                  1                 2.0
# 148               1                  1                 1.0
# 386               1                  1                 1.0
# 612               1                  1                 2.0
# 801               1                  1                 1.0
# 334               1                  1                 1.0
# 657               1                  1                 1.0
# 747               1                  1                 2.0
# 394               1                  1                 1.0
# 998               1                  1                 0.0
# 822               1                  1                 2.0
# 278               1                  1                 3.0
# 1025              1                  1                 1.0
# 1008              1                  1                 1.0
# 222               1                  1                 1.0
# 618              -1                 -1                -0.0
# 582               1                  1                 2.0
# 733               1                  1                 1.0
# 398               1                  1                 2.0
# 135               1                  1                 1.0
# 777               1                  1                 2.0
# 262               1                  1                 3.0
# 864               1                  1                 1.0
# 917               1                  1                 2.0
# 743               1                  1                 1.0
# 371               1                  1                 2.0
# 548               1                  1                 1.0
# ...             ...                ...                 ...
# 1001              1                 -1                -0.0
# 735               1                  1                 0.0
# 245               1                 -1                -0.0
# 363               1                 -1                -1.0
# 502               1                 -1                -0.0
# 452              -1                 -1                -2.0
# 1002             -1                 -1                -1.0
# 763              -1                 -1                -1.0
# 977               1                 -1                -0.0
# 411               1                 -1                -0.0
# 455              -1                 -1                -1.0
# 63               -1                 -1                -0.0
# 395               1                 -1                -1.0
# 524              -1                 -1                -1.0
# 378               1                 -1                -0.0
# 987              -1                 -1                -2.0
# 55                1                 -1                -0.0
# 1026              1                 -1                -0.0
# 133              -1                 -1                -2.0
# 239              -1                 -1                -2.0
# 140              -1                 -1                -1.0
# 203               1                 -1                -0.0
# 993               1                 -1                -0.0
# 955              -1                 -1                -1.0
# 58               -1                 -1                -2.0
# 356               1                 -1                -0.0
# 105              -1                 -1                -1.0
# 714              -1                 -1                -0.0
# 708              -1                 -1                -1.0
# 402              -1                 -1                -2.0
#
#       ABS_REB_PCT_DIFF_GROUP  IS_SIGN_POSITIVE
# 342                      1.0                 1
